# %% [markdown]
# <a href="https://colab.research.google.com/github/AshwathiE/nlp/blob/main/Untitled23.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Set seeds for reproducibility
import random
random.seed(0)

import numpy as np
np.random.seed(0)

import tensorflow as tf
tf.random.set_seed(0)

# %%
import os
import json
from zipfile import ZipFile
from PIL import Image

import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras import layers, models

# %%
# !pip install kaggle

# %%
kaggle_credentails = json.load(open("kaggle.json"))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-4-8f659ac12673> in <cell line: 1>()
# ----> 1 kaggle_credentails = json.load(open("kaggle.json"))
#
# FileNotFoundError: [Errno 2] No such file or directory: 'kaggle.json'

# %%
# setup Kaggle API key as environment variables
os.environ['KAGGLE_USERNAME'] = kaggle_credentails["username"]
os.environ['KAGGLE_KEY'] = kaggle_credentails["key"]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-cb6f8e6b6342> in <cell line: 2>()
#       1 # setup Kaggle API key as environment variables
# ----> 2 os.environ['KAGGLE_USERNAME'] = kaggle_credentails["username"]
#       3 os.environ['KAGGLE_KEY'] = kaggle_credentails["key"]
#
# NameError: name 'kaggle_credentails' is not defined

# %%
! kaggle datasets download -d shubham2703/five-crop-diseases-dataset
# Out:
# Dataset URL: https://www.kaggle.com/datasets/shubham2703/five-crop-diseases-dataset
# License(s): CC-BY-NC-SA-4.0
# ...
# 100% 4.32G/4.33G [00:54<00:00, 159MB/s]
# 100% 4.33G/4.33G [00:54<00:00, 85.2MB/s]

# %%
# !ls
# Out:
# five-crop-diseases-dataset.zip	sample_data

# %%
# Unzip the downloaded dataset
with ZipFile("/content/five-crop-diseases-dataset.zip", 'r') as zip_ref:
    zip_ref.extractall()

# %%
print(os.listdir("Crop Diseases Dataset"))


print(len(os.listdir("/content/Crop Diseases Dataset/Crop Diseases/Crop___Disease/Corn")))
print(os.listdir("/content/Crop Diseases Dataset/Crop Diseases/Crop___Disease/Corn")[:5])

print(len(os.listdir("/content/Crop Diseases Dataset/Crop Diseases/Crop___Disease/Potato")))
print(os.listdir("/content/Crop Diseases Dataset/Crop Diseases/Crop___Disease/Potato")[:5])

print(len(os.listdir("/content/Crop Diseases Dataset/Crop Diseases/Crop___Disease/Rice")))
print(os.listdir("/content/Crop Diseases Dataset/Crop Diseases/Crop___Disease/Rice")[:5])

print(len(os.listdir("/content/Crop Diseases Dataset/Crop Diseases/Crop___Disease/Wheat")))
print(os.listdir("/content/Crop Diseases Dataset/Crop Diseases/Crop___Disease/Wheat")[:5])

print(len(os.listdir("/content/Crop Diseases Dataset/Crop Diseases/Crop___Disease/sugarcane")))
print(os.listdir("/content/Crop Diseases Dataset/Crop Diseases/Crop___Disease/sugarcane")[:5])
# Out:
# ['Crop Diseases', 'Info.txt']
# 4
# ['Corn___Northern_Leaf_Blight', 'Corn___Common_Rust', 'Corn___Gray_Leaf_Spot', 'Corn___Healthy']
# 3
# ['Potato___Healthy', 'Potato___Late_Blight', 'Potato___Early_Blight']
# 4
# ['Rice___Healthy', 'Rice___Neck_Blast', 'Rice___Leaf_Blast', 'Rice___Brown_Spot']
# 3
# ['Wheat___Healthy', 'Wheat___Yellow_Rust', 'Wheat___Brown_Rust']
# 3
# ['Red Rot', 'Healthy', 'Bacterial Blight']

# %%
print(len(os.listdir("/content/Crop Diseases Dataset/Crop Diseases/Crop___Disease/Rice/Rice___Healthy")))
print(os.listdir("/content/Crop Diseases Dataset/Crop Diseases/Crop___Disease/Rice/Rice___Healthy")[:5])
# Out:
# 1488
# ['IMG_3234.jpg', 'IMG_20190419_095003.jpg', 'IMG_20190419_165828.jpg', 'IMG_20190419_174605.jpg', 'IMG_20190419_163401.jpg']

# %%
base_dir = '/content/Crop Diseases Dataset/Crop Diseases/Crop___Disease'

# %%
image_path = '/content/Crop Diseases Dataset/Crop Diseases/Crop___Disease/Rice/Rice___Healthy/IMG_20190419_094251.jpg'

# Read the image
img = mpimg.imread(image_path)

print(img.shape)
# Display the image
plt.imshow(img)
plt.axis('off')  # Turn off axis numbers
plt.show()
# Out:
# (256, 256, 3)

# %%
image_path = '/content/Crop Diseases Dataset/Crop Diseases/Crop___Disease/Rice/Rice___Healthy/IMG_20190419_094251.jpg'

# Read the image
img = mpimg.imread(image_path)

print(img)
# Out:
# [[[173 188 253]
#   [173 188 253]
#   [173 188 253]
#   ...
#   [179 188 253]
#   [179 188 253]
#   [179 188 253]]
#
#  [[173 188 253]
#   [173 188 253]
#   [173 188 253]
#   ...
#   [179 188 253]
#   [179 188 253]
#   [179 188 253]]
#
#  [[173 188 253]
#   [173 188 253]
#   [173 188 253]
#   ...
#   [179 188 253]
#   [179 188 253]
#   [179 188 253]]
#
#  ...
#
#  [[158 172 245]
#   [158 172 245]
#   [158 172 245]
#   ...
#   [159 169 240]
#   [160 170 241]
#   [160 170 241]]
#
#  [[158 172 245]
#   [158 172 245]
#   [158 172 245]
#   ...
#   [161 169 241]
#   [161 169 241]
#   [161 169 241]]
#
#  [[158 172 245]
#   [158 172 245]
#   [158 172 245]
#   ...
#   [161 169 241]
#   [161 169 241]
#   [161 169 241]]]

# %%
# Image Parameters
img_size = 214
batch_size = 32

# %%
# Image Data Generators
data_gen = ImageDataGenerator(
    rescale=1./227,
    validation_split=0.2  # Use 20% of data for validation
)

# %%
train_generator = data_gen.flow_from_directory(
    base_dir,
    target_size=(img_size, img_size),
    batch_size=batch_size,
    subset='training',
    class_mode='categorical'
)
# Out:
# Found 10661 images belonging to 5 classes.

# %%
# Validation Generator
validation_generator = data_gen.flow_from_directory(
    base_dir,
    target_size=(img_size, img_size),
    batch_size=batch_size,
    subset='validation',
    class_mode='categorical'
)
# Out:
# Found 2663 images belonging to 5 classes.

# %%
from tensorflow.keras import layers, models

# Define model
model = models.Sequential()

# First convolutional layer with more filters and larger kernel size
model.add(layers.Conv2D(64, (5, 5), activation='relu', input_shape=(img_size, img_size, 3)))
model.add(layers.MaxPooling2D(2, 2))

# Second convolutional layer with more filters
model.add(layers.Conv2D(128, (3, 3), activation='relu'))
model.add(layers.MaxPooling2D(2, 2))

# Third convolutional layer added
model.add(layers.Conv2D(256, (3, 3), activation='relu'))
model.add(layers.MaxPooling2D(2, 2))

# Flatten and dense layers with modified units
model.add(layers.Flatten())
model.add(layers.Dense(512, activation='relu'))
model.add(layers.Dense(train_generator.num_classes, activation='softmax'))

# Print model summary
model.summary()
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                      │ (None, 210, 210, 64)        │           4,864 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d (MaxPooling2D)         │ (None, 105, 105, 64)        │               0 │
# ...

# %%
model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# %%
# Training the Model
history = model.fit(
    train_generator,
    steps_per_epoch=train_generator.samples // batch_size,  # Number of steps per epoch
    epochs=5,  # Number of epochs
    validation_data=validation_generator,
    validation_steps=validation_generator.samples // batch_size  # Validation steps
)
# Out:
# Epoch 1/5
# /usr/local/lib/python3.10/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 333/333 ━━━━━━━━━━━━━━━━━━━━ 4285s 13s/step - accuracy: 0.7694 - loss: 0.7986 - val_accuracy: 0.9639 - val_loss: 0.0955
# Epoch 2/5
#   1/333 ━━━━━━━━━━━━━━━━━━━━ 1:08:44 12s/step - accuracy: 1.0000 - loss: 0.0706
# /usr/lib/python3.10/contextlib.py:153: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self.gen.throw(typ, value, traceback)
# ...

# %%
# Model Evaluation
print("Evaluating model...")
val_loss, val_accuracy = model.evaluate(validation_generator, steps=validation_generator.samples // batch_size)
print(f"Validation Accuracy: {val_accuracy * 100:.2f}%")
# Out:
# Evaluating model...
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 279s 3s/step - accuracy: 0.9185 - loss: 0.2845
# Validation Accuracy: 92.62%

# %%
# Plot training & validation accuracy values
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# Plot training & validation loss values
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# %%
# Function to Load and Preprocess the Image using Pillow
def load_and_preprocess_image(image_path, target_size=(214, 214)):
    # Load the image
    img = Image.open(image_path)
    # Resize the image
    img = img.resize(target_size)
    # Convert the image to a numpy array
    img_array = np.array(img)
    # Add batch dimension
    img_array = np.expand_dims(img_array, axis=0)
    # Scale the image values to [0, 1]
    img_array = img_array.astype('float32') / 255.
    return img_array

# Function to Predict the Class of an Image
def predict_image_class(model, image_path, class_indices):
    preprocessed_img = load_and_preprocess_image(image_path)
    predictions = model.predict(preprocessed_img)
    predicted_class_index = np.argmax(predictions, axis=1)[0]
    predicted_class_name = class_indices[predicted_class_index]
    return predicted_class_name

# %%
class_indices = {v: k for k, v in train_generator.class_indices.items()}

# %%
class_indices
# Out:
# {0: 'Corn', 1: 'Potato', 2: 'Rice', 3: 'Wheat', 4: 'sugarcane'}

# %%
json.dump(class_indices, open('class_indices.json', 'w'))

# %%
# Example Usage
image_path = '/content/Crop Diseases Dataset/Crop Diseases/Crop___Disease/Potato/Potato___Early_Blight/001187a0-57ab-4329-baff-e7246a9edeb0___RS_Early.B 8178.JPG'
#image_path = '/content/Crop Diseases Dataset/Crop Diseases/Crop___Disease/Potato/Potato___Early_Blight/001187a0-57ab-4329-baff-e7246a9edeb0___RS_Early.B 8178.JPG'
#image_path = '/content/Crop Diseases Dataset/Crop Diseases/Crop___Disease/Potato/Potato___Early_Blight/001187a0-57ab-4329-baff-e7246a9edeb0___RS_Early.B 8178.JPG'
predicted_class_name = predict_image_class(model, image_path, class_indices)

# Output the result
print("Predicted Class Name:", predicted_class_name)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 255ms/step
# Predicted Class Name: Potato
